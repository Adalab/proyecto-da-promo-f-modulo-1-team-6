# %% [markdown]
# # Preguntas y Respuestas
#
#
# - Reglas del Juego de "Preguntas y Respuestas de Geografía":
#     - El juego consiste en hacer preguntas de geografía y que el jugador adivine la respuesta correcta.
#
#     - Cada pregunta tiene una respuesta única y correcta.
#
#     - El jugador tiene un número limitado de intentos para responder correctamente a cada pregunta.
#
#     - El juego sigue hasta que el jugador responda incorrectamente 3 de veces o haya respondido 5 preguntas correctamente.
#
#
# - Pistas para las alumnas:
#
#     1. Comienza creando un diccionario que contenga preguntas de geografía como claves y respuestas como valores.
#
#     2. Implementa una función para seleccionar una pregunta aleatoria del diccionario.
#
#     3. Utiliza un bucle `while` para hacer preguntas de geografía hasta que el jugador responda un número específico de preguntas correctamente o alcance un número máximo de respuestas incorrectas.
#
#     4. Dentro del bucle, presenta la pregunta al jugador y permita que ingresen sus respuestas.
#
#     5. Lleva un seguimiento del número de preguntas realizadas y el número de respuestas correctas.
#
#     6. Determina las condiciones de victoria y derrota del juego y sal del bucle cuando se cumplan estas condiciones.

# %%
import random
jugador = input("Nombre del jugador")
print("Hola,", jugador, "Vamos a jugar a Preguntas y respuestas de Geografía. Ganaras si consigues 5 puntos.")

juego = input("¿Preparade para jugar? S/N").upper()

# En este primer bucle se dan las opciones para iniciar, repetir y terminar el juego.
while juego == "S":

    print("¡Vamos allá!\n")

    # Definición de diccionario:
    diccionario = {"¿Cuál es el río más largo del mundo?": "Nilo",
                   "¿Cuál es la capital de Honduras?": "Tegucigalpa",
                   "¿Cuál es el lago con mayor altitud?": "Titicaca",
                   "¿Cuál es la isla más extensa?": "Groenlandia",
                   "¿Cuántos mares existen en el mundo?": "60"}
    #implementar función para pregunta aleatoria:
    puntuacion = 0
    oportunidades = 5
    fallos = 3

    while (puntuacion < 5 and oportunidades > 0 and fallos > 0):

        pregunta= random.choice(list(diccionario.keys()))
        respuesta= diccionario[pregunta]
        jugador = input(f"{pregunta} Tu respuesta: ").strip()
        print(pregunta)
    
        
        if jugador.lower() == respuesta.lower():
            print("¡Correcto! Has ganado 1 punto")
            print("                                     ")
            puntuacion += 1
            print(f"Tienes {puntuacion} puntos")
            print("--------------------------------------")
        else:
            fallos -= 1
            oportunidades -= 1
            print(f"Incorrecto. La respuesta correcta es: {respuesta}. Solo puedes fallar {fallos} veces más.")
            print("                                      ")
            print(f"Tienes {oportunidades} oportunidades más para completar el juego")
            print("                                      ")
            print(f"Tienes {puntuacion} puntos")
            print("--------------------------------------")

        del diccionario[pregunta]

    if puntuacion == 5:
        print(f"¡Enhorabuena, {jugador}! Has ganado.")
        juego = input("¿Quieres jugar otra vez? S/N: ").upper()  # Aquí se actualiza "juego"
    else:
        fallos = 3
        print(f"Lo siento, {jugador}, has perdido :(.") 
        juego = input("¿Quieres jugar otra vez? S/N: ").upper()  # Aquí se actualiza "juego"
# Out:
# Hola, eli Vamos a jugar a Preguntas y respuestas de Geografía. Ganaras si consigues 5 puntos.
# ¡Vamos allá!
#
# ¿Cuál es el lago con mayor altitud?
# ¡Correcto! Has ganado 1 punto
#
# Tienes 1 puntos
# --------------------------------------
# ¿Cuántos mares existen en el mundo?
# ¡Correcto! Has ganado 1 punto
#
# Tienes 2 puntos
# --------------------------------------
# ¿Cuál es la isla más extensa?
# ¡Correcto! Has ganado 1 punto
#
# Tienes 3 puntos
# --------------------------------------
# ¿Cuál es la capital de Honduras?
# Incorrecto. La respuesta correcta es: Tegucigalpa. Solo puedes fallar 2 veces más.
#
# Tienes 4 oportunidades más para completar el juego
#
# Tienes 3 puntos
# --------------------------------------
# ¿Cuál es el río más largo del mundo?
# ¡Correcto! Has ganado 1 punto
#
# Tienes 4 puntos
# --------------------------------------
# ---------------------------------------------------------------------------
# ...

# %%
import random

# Definición de preguntas y respuestas
preguntas_respuestas = {
    "¿Cuál es la capital de Francia?": "París",
    "¿En qué año se fundó Google?": "1998",
    "¿Cuál es el planeta más grande del sistema solar?": "Júpiter",
    "¿Cuál es el río más largo del mundo?": "El Nilo",
    "¿Quién escribió 'Romeo y Julieta'?": "William Shakespeare",
}

# Función para jugar
def jugar_preguntas_respuestas():
    puntaje = 0
    #continuar = True

    while True:
        # Seleccionar una pregunta al azar
        pregunta, respuesta = random.choice(list(preguntas_respuestas.items()))
        #print(pregunta)
        respuesta_usuario = input(f"{pregunta} Tu respuesta: ")
        if respuesta_usuario.lower() == respuesta.lower():
            print("¡Correcto!\n")
            puntaje += 1
        else:
            print(f"Respuesta incorrecta. La respuesta correcta es: {respuesta}\n")

        # Eliminar la pregunta utilizada
        del preguntas_respuestas[pregunta]

        if not preguntas_respuestas:
            print("Has respondido todas las preguntas.")
            break
        
        respuesta = input("¿Quieres jugar de nuevo con una pregunta aleatoria? (sí/no): ")
        if respuesta.lower() != "sí":
            continuar = False

    print(f"Has obtenido {puntaje} de {len(list(preguntas_respuestas)) + puntaje} preguntas correctas.")

# Iniciar el juego
print("¡Bienvenido al juego de preguntas y respuestas!")
jugar_preguntas_respuestas()

# %%
import random

# Diccionario de preguntas y respuestas
preguntas_respuestas = {
    "¿Cuál es la capital de Francia?": "París",
    "¿En qué año se fundó Apple Inc.?": "1976",
    "¿Cuál es el planeta más grande del sistema solar?": "Júpiter",
    "¿Quién escribió 'Romeo y Julieta'?": "William Shakespeare",
    "¿Cuál es el elemento químico con símbolo 'H'?": "Hidrógeno"
}

# Obtener una lista de preguntas
preguntas = list(preguntas_respuestas.keys())

while True:
    # Elegir una pregunta aleatoria
    pregunta = random.choice(preguntas)
    
    # Obtener la respuesta correcta
    respuesta_correcta = preguntas_respuestas[pregunta]
    
    # Mostrar la pregunta y obtener la respuesta del jugador
    print("Pregunta: ", pregunta)
    respuesta_usuario = input(f"{pregunta} Tu respuesta: ").strip()
    
    # Comprobar si la respuesta es correcta
    if respuesta_usuario.lower() == respuesta_correcta.lower():
        print("¡Respuesta correcta!")
    else:
        print(f"Respuesta incorrecta. La respuesta correcta es: {respuesta_correcta}")
    
    break
    # Preguntar al jugador si desea jugar nuevamente
jugar_nuevamente = input("¿Deseas jugar nuevamente? (s/n): ").strip().lower()
if jugar_nuevamente = "s":
    print("vamos!")
else:
# Out:
#   File "/tmp/ipykernel_474551/2773701463.py", line 36
#
#     ^
# IndentationError: expected an indented block

# %%
import random

# Diccionario de preguntas y respuestas
preguntas_respuestas = {
    "¿Cuál es la capital de Francia?": "París",
    "¿En qué año se fundó Apple Inc.?": "1976",
    "¿Cuál es el planeta más grande del sistema solar?": "Júpiter",
    "¿Quién escribió 'Romeo y Julieta'?": "William Shakespeare",
    "¿Cuál es el elemento químico con símbolo 'H'?": "Hidrógeno"
}

# Obtener una lista de preguntas
preguntas = list(preguntas_respuestas.keys())

# Inicializar la puntuación del jugador y el contador de fallos
puntuacion = 0
fallos = 0

# Inicializar una lista para llevar un registro de las preguntas realizadas
preguntas_realizadas = []

while puntuacion < 5 and fallos < 3:  # El juego se ejecuta hasta que el jugador alcance 5 puntos o cometa 3 fallos
    # Elegir una pregunta aleatoria que no se haya realizado
    pregunta = random.choice(preguntas)
    while pregunta in preguntas_realizadas:
        pregunta = random.choice(preguntas)
    
    preguntas_realizadas.append(pregunta)
    
    # Obtener la respuesta correcta
    respuesta_correcta = preguntas_respuestas[pregunta]
    
    # Mostrar la pregunta y obtener la respuesta del jugador
    print("Pregunta:", pregunta)
    respuesta_usuario = input(f"{pregunta} Tu respuesta: ").strip()
    
    # Comprobar si la respuesta es correcta
    if respuesta_usuario.lower() == respuesta_correcta.lower():
        print("¡Respuesta correcta!")
        puntuacion += 1  # Incrementar la puntuación en 1 punto
        print("Puntuación actual:", puntuacion)
    else:
        print(f"Respuesta incorrecta. La respuesta correcta es: {respuesta_correcta}")
        fallos += 1  # Incrementar el contador de fallos en 1
    
print("¡Juego terminado!")
if puntuacion == 5:
    print("¡Felicidades! Has alcanzado 5 puntos y has ganado el juego.")
else:
    print("Has cometido 3 fallos. Mejor suerte la próxima vez.")
# Out:
# Pregunta: ¿Quién escribió 'Romeo y Julieta'?
# Respuesta incorrecta. La respuesta correcta es: William Shakespeare
# Pregunta: ¿En qué año se fundó Apple Inc.?
# ¡Respuesta correcta!
# Puntuación actual: 1
# Pregunta: ¿Cuál es la capital de Francia?
# ¡Respuesta correcta!
# Puntuación actual: 2
# Pregunta: ¿Cuál es el elemento químico con símbolo 'H'?
# ¡Respuesta correcta!
# Puntuación actual: 3
# Pregunta: ¿Cuál es el planeta más grande del sistema solar?
# ¡Respuesta correcta!
# Puntuación actual: 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_474551/4232104433.py in <module>
#      24     pregunta = random.choice(preguntas)
#      25     while pregunta in preguntas_realizadas:
# ---> 26         pregunta = random.choice(preguntas)
#      27
#      28     preguntas_realizadas.append(pregunta)
#
# ~/anaconda3/lib/python3.9/random.py in choice(self, seq)
# ...

# %%
import random

# Diccionario de preguntas y respuestas
preguntas_respuestas = {
    "¿Cuál es la capital de Francia?": "París",
    "¿En qué año se fundó Apple Inc.?": "1976",
    "¿Cuál es el planeta más grande del sistema solar?": "Júpiter",
    "¿Quién escribió 'Romeo y Julieta'?": "William Shakespeare",
    "¿Cuál es el elemento químico con símbolo 'H'?": "Hidrógeno"
}

# Obtener una lista de preguntas
preguntas = list(preguntas_respuestas.keys())

# Inicializar la puntuación del jugador y el contador de fallos
puntuacion = 0
fallos = 0

# Inicializar una lista para llevar un registro de las preguntas realizadas
preguntas_realizadas = []

while puntuacion < 5 and fallos < 3:  # El juego se ejecuta hasta que el jugador alcance 5 puntos o cometa 3 fallos
    # Elegir una pregunta aleatoria que no se haya realizado
    pregunta = random.choice(preguntas)
    while pregunta in preguntas_realizadas:
        pregunta = random.choice(preguntas)
    
    preguntas_realizadas.append(pregunta)
    
    # Obtener la respuesta correcta
    respuesta_correcta = preguntas_respuestas[pregunta]
    
    # Mostrar la pregunta y obtener la respuesta del jugador
    print("Pregunta:", pregunta)
    respuesta_usuario = input(f"{pregunta} Tu respuesta: ").strip()
    
    # Comprobar si la respuesta es correcta
    if respuesta_usuario.lower() == respuesta_correcta.lower():
        print("¡Respuesta correcta!")
        puntuacion += 1  # Incrementar la puntuación en 1 punto
        print("Puntuación actual:", puntuacion)
    else:
        print(f"Respuesta incorrecta. La respuesta correcta es: {respuesta_correcta}")
        fallos += 1  # Incrementar el contador de fallos en 1
    
print("¡Juego terminado!")
if puntuacion == 5:
    print("¡Felicidades! Has alcanzado 5 puntos y has ganado el juego.")
else:
    print("Has cometido 3 fallos. Mejor suerte la próxima vez.")
# Out:
# Pregunta: ¿Cuál es el planeta más grande del sistema solar?
# ¡Respuesta correcta!
# Puntuación actual: 1
# Pregunta: ¿Cuál es el elemento químico con símbolo 'H'?
# ¡Respuesta correcta!
# Puntuación actual: 2
# Pregunta: ¿Quién escribió 'Romeo y Julieta'?
# ¡Respuesta correcta!
# Puntuación actual: 3
# Pregunta: ¿En qué año se fundó Apple Inc.?
# ¡Respuesta correcta!
# Puntuación actual: 4
# Pregunta: ¿Cuál es la capital de Francia?
# ¡Respuesta correcta!
# Puntuación actual: 5
# ¡Juego terminado!
# ¡Felicidades! Has alcanzado 5 puntos y has ganado el juego.
